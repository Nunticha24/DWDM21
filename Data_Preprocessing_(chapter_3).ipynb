# %% [markdown]
# <a href="https://colab.research.google.com/github/Nunticha24/DWDM21/blob/main/Data_Preprocessing_(chapter_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #ข้อมูลลักษณะ ตาราง

# %%
from google.colab import drive #เชื่่อมกับ google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการไฟล์และpath

# %%
path = '/content/drive/My Drive/DWDM2021_DATA'
data_cases = pd.read_csv(os.path.join(path, 'confirmed-cases.csv'))
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# ## Meta Data (Data ที่ใช้อธิบาย Data)

# %% [markdown]
# ## ชี้ข้อมูลในตาราง

# %% [markdown]
# ### ชี้แบบธรรมดา ใช้ [ชื่อ column ,Index]

# %%
data_cases['risk'] #ชี้ข้อมูล column ที่เลือก
# Out:
# 0         คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         คนต่างชาติเดินทางมาจากต่างประเทศ
#                         ...
# 512617                    ทัณฑสถาน/เรือนจำ
# 512618                    ทัณฑสถาน/เรือนจำ
# 512619                    ทัณฑสถาน/เรือนจำ
# 512620                    ทัณฑสถาน/เรือนจำ
# 512621                    ทัณฑสถาน/เรือนจำ
# Name: risk, Length: 512622, dtype: object

# %%
data_cases['risk'][678] #ชี้แบบเลือก column แล้วเลือก Index
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
data_cases[['age','risk','sex']] #ชี้แบบหลาย column
# Out:
#          age                              risk   sex
# 0       61.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 1       74.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 2       73.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# 3       68.0  คนต่างชาติเดินทางมาจากต่างประเทศ   ชาย
# 4       66.0  คนต่างชาติเดินทางมาจากต่างประเทศ  หญิง
# ...      ...                               ...   ...
# 512617   NaN                  ทัณฑสถาน/เรือนจำ   ชาย
# 512618   NaN                  ทัณฑสถาน/เรือนจำ   ชาย
# 512619   NaN                  ทัณฑสถาน/เรือนจำ   ชาย
# 512620   NaN                  ทัณฑสถาน/เรือนจำ   ชาย
# 512621   NaN                  ทัณฑสถาน/เรือนจำ   ชาย
#
# [512622 rows x 3 columns]

# %% [markdown]
# ### ชี้แบบ .iloc[] (มองข้อมูลเป็น Matrix)

# %%
data_cases.iloc[678,8]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
data_cases.iloc[-10:,4:9:2]
# Out:
#         age nationality              risk
# 512612  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512613  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512614  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512615  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512616  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512617  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512618  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512619  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512620  NaN         NaN  ทัณฑสถาน/เรือนจำ
# 512621  NaN         NaN  ทัณฑสถาน/เรือนจำ

# %%
data_cases.iloc[-10:,[3,4,8]]
# Out:
#          sex  age              risk
# 512612  หญิง  NaN  ทัณฑสถาน/เรือนจำ
# 512613   ชาย  NaN  ทัณฑสถาน/เรือนจำ
# 512614   ชาย  NaN  ทัณฑสถาน/เรือนจำ
# 512615   ชาย  NaN  ทัณฑสถาน/เรือนจำ
# 512616   ชาย  NaN  ทัณฑสถาน/เรือนจำ
# 512617   ชาย  NaN  ทัณฑสถาน/เรือนจำ
# 512618   ชาย  NaN  ทัณฑสถาน/เรือนจำ
# 512619   ชาย  NaN  ทัณฑสถาน/เรือนจำ
# 512620   ชาย  NaN  ทัณฑสถาน/เรือนจำ
# 512621   ชาย  NaN  ทัณฑสถาน/เรือนจำ

# %%
data_cases.describe()
# Out:
#                  No.            age
# count  512622.000000  462839.000000
# mean   256311.500000      35.529470
# std    147981.369183      16.153885
# min         1.000000       1.000000
# 25%    128156.250000      25.000000
# 50%    256311.500000      34.000000
# 75%    384466.750000      46.000000
# max    512622.000000     108.000000

# %%
from matplotlib import pyplot as plt
plt.boxplot(data_cases['age']) #plot ไม่ได้ เพราะมีค่า Missing
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fce161ac9d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fce161b7a90>,
#   <matplotlib.lines.Line2D at 0x7fce161b7fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fce161bfad0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fce161bf590>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fce1623ae90>,
#   <matplotlib.lines.Line2D at 0x7fce161b7550>]}

# %% [markdown]
# # Missing Values
#
# *   NaN = Not a Number
# *   Null
# *   NA = Not Avaiiable

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull() #บอกว่าตรงไหนเป็นช่องว่าง
# Out:
#           No.  announce_date  ...  province_of_onset  district_of_onset
# 0       False          False  ...              False               True
# 1       False          False  ...              False               True
# 2       False          False  ...              False              False
# 3       False          False  ...              False               True
# 4       False          False  ...              False               True
# ...       ...            ...  ...                ...                ...
# 512617  False          False  ...               True               True
# 512618  False          False  ...               True               True
# 512619  False          False  ...               True               True
# 512620  False          False  ...               True               True
# 512621  False          False  ...               True               True
#
# [512622 rows x 11 columns]

# %%
data_cases.isnull().any() #สรุปข้อมูลเป็น column
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# Handling Missing Value 1 (ลบค่า missing)

# %%
plt.boxplot(data_cases['age'].dropna()) # dropna ลบค่า missing
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fce15d01cd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fce15d0dcd0>,
#   <matplotlib.lines.Line2D at 0x7fce15d11210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fce15d11cd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fce15d11790>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fce15d0d210>,
#   <matplotlib.lines.Line2D at 0x7fce15d0d750>]}

# %%
data_cases.dropna()
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 47          48      6/3/2020  ...     กรุงเทพมหานคร           คลองตัน
# 124        125      6/3/2021  ...          ปทุมธานี           ธัญบุรี
# 161        162     17/3/2020  ...      สุราษฎร์ธานี             เมือง
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 186        187     18/3/2020  ...          ร้อยเอ็ด         เชียงขวัญ
# ...        ...           ...  ...               ...               ...
# 511575  511576     26/7/2021  ...     กรุงเทพมหานคร           มีนบุรี
# 511577  511578     26/7/2021  ...     กรุงเทพมหานคร            บางบอน
# 511578  511579     26/7/2021  ...     กรุงเทพมหานคร           ทุ่งครุ
# 511579  511580     26/7/2021  ...     กรุงเทพมหานคร             พญาไท
# 511580  511581     26/7/2021  ...     กรุงเทพมหานคร           มีนบุรี
#
# [362205 rows x 11 columns]

# %%
data_cases.dropna().shape # .shape จะแสดงผลแถวกับคอลัมน์
# Out:
# (362205, 11)

# %%
data_cases.dropna().shape[0]
# Out:
# 362205

# %% [markdown]
# ### Quiz 3 ให้หาว่า การทำ dropna() ทำให้ข้อมูลหายไปกี่% (11.05)
#
# ```
# size before drop = 1000
# size after drop = 19
# we loss 99% of data
#
# ```

# %%
after = data_cases.shape[0] - data_cases.dropna().shape[0]
after
# Out:
# 150417

# %%
data_af = (after/data_cases.shape[0])*100
data_af
# Out:
# 29.342673548930794

# %%
#เฉลย
removed = data_cases.shape[0] - data_cases.dropna().shape[0]
print(f'size before drop = {data_cases.shape[0]}')
print(f'size after drop = {data_cases.dropna().shape[0]}')
print(f'we lost {100*(removed/data_cases.shape[0])}% of data')
# Out:
# size before drop = 512622
# size after drop = 362205
# we lost 29.342673548930794% of data

# %% [markdown]
# ## Handling Missing Value 1.5 (ลบค่า missing เฉพาะใน column ที่เราสนใจ)

# %%
data_cases_nomissingAge = data_cases.dropna(subset=['age'])

# %%
plt.boxplot(data_cases_nomissingAge['age'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fce15207590>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fce1520c650>,
#   <matplotlib.lines.Line2D at 0x7fce1520cb90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fce15214690>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fce15214150>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fce15207b90>,
#   <matplotlib.lines.Line2D at 0x7fce1520c110>]}

# %% [markdown]
# ### Quiz 3.1 ให้หาว่า การทำ dropna() แบบเลือก drop เฉพาะ column ที่เราสนใจ (age) ทำให้ข้อมูลหายไปกี่%

# %%
removed = data_cases.shape[0] - data_cases_nomissingAge.shape[0]
print(f'size before drop = {data_cases.shape[0]}')
print(f'size after drop = {data_cases_nomissingAge.shape[0]}')
print(f'we lost {100*(removed/data_cases.shape[0])}% of data')
# Out:
# size before drop = 512622
# size after drop = 462839
# we lost 9.711444300088564% of data

# %% [markdown]
# ## Handling Missing Value 2 (แทนด้วย class ใหม่ (unknow))

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases[['risk']] = data_cases[['risk']].fillna('ไม่มีข้อมูล')

# %%
set(data_cases['risk'])
# Out:
# {'2.สัมผัสผู้ติดเชื้อ',
#  'ACF รองเมือง',
#  'ACF สนามกีฬาธูปะเตมีย์',
#  'ACF สนามกีฬาไทย-ญี่ปุ่น',
#  'ACF สีลม',
#  'ACF เคหะหลักสี่',
#  'Cluster Icon siam',
#  "Cluster Memory 90's กรุงเทพมหานคร",
#  'Cluster New Jazz กรุงเทพมหานคร',
#  'Cluster The Lounge Salaya',
#  'Cluster กรุงเทพมหานคร. คลองเตย',
#  'Cluster คลองเตย',
#  'Cluster งานมอเตอร์ โชว์',
#  'Cluster จนท. สนามบินสุวรรณภูมิ',
#  'Cluster จันทบุรี',
#  'Cluster จันทบุรี (ชาวกินี )',
#  'Cluster จันทบุรี (ชาวกินี)',
#  'Cluster ชลบุรี',
#  'Cluster ชลบุรี บริษัทไดกิ้น',
#  'Cluster ชลบุรี โรงเบียร์ 90',
#  'Cluster ตราด',
#  'Cluster ตราด ',
#  'Cluster ตลาดนนทบุรี',
#  'Cluster ตลาดบางพลี',
#  'Cluster ตลาดบางแค',
#  'Cluster ตลาดบางแค/คลองขวาง',
#  'Cluster ตลาดพรพัฒน์',
#  'Cluster ตลาดสี่มุมเมือง',
#  'Cluster ทัณฑสถานหญิงกลาง',
#  'Cluster ทัณฑสถานโรงพยาบาลราชทัณฑ์',
#  'Cluster ทันฑสถานบำบัดพิเศษกลาง',
#  'Cluster บริษัทศรีสวัสดิ์',
#  'Cluster บางแค',
#  'Cluster บ่อนพัทยา/ชลบุรี',
#  'Cluster บ่อนเทพารักษ์',
#  'Cluster บ่อนไก่อ่างทอง',
#  'Cluster ปากช่อง',
#  'Cluster ผับ Thonglor',
#  'Cluster มหาสารคาม',
#  'Cluster ระยอง',
#  'Cluster ระยอง วิริยะประกันภัย',
#  'Cluster สถานบันเทิงย่านทองหล่อ',
#  'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)',
#  'Cluster สมุทรปราการ GRP Hightech',
#  'Cluster สมุทรปราการ ตลาดเคหะบางพลี',
#  'Cluster สมุทรสาคร',
#  'Cluster ห้างแสงทอง (สายล่าง)',
#  'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)',
#  'Cluster เรือนจำกลางคลองเปรม',
#  'Cluster เรือนจำพิเศษกรุงเทพ',
#  'Cluster เรือนจำพิเศษธนบุรี',
#  'Cluster เรือนจำพิเศษมีนบุรี',
#  'Cluster โรงงาน  Big Star',
#  'Cluster โรงงาน Big Star',
#  'Cluster โรงงาน QPP ประจวบฯ',
#  'Cluster โรงงาน standard can',
#  'Cluster โรงงานทำขนม บางขุนเทียน',
#  'Refer in',
#  'SHUI',
#  'Sandbox',
#  'State Quarantine',
#  'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)',
#  'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน',
#  'คนต่างชาติเดินทางมาจากต่างประเทศ',
#  'คนไทยมาจากพื้นที่เสี่ยง',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คนไทยเดินทางมาจากต่างประเทศ',
#  'ค้นหาเชิงรุก',
#  'ตรวจก่อนทำหัตถการ',
#  'ตรวจสุขภาพแรงงานต่างด้าว',
#  'ตลาด',
#  'ทัณฑสถาน/เรือนจำ',
#  'บุคลากรด้านการแพทย์และสาธารณสุข',
#  'ปอดอักเสบ (Pneumonia)',
#  'ปอดอักเสบ Pneumonia',
#  'ผับหัวหิน',
#  'ผู้ติดเชื้อในประเทศ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ',
#  'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ',
#  'ผู้ป่วย PUI',
#  'ผู้ป่วย กรุงเทพมหานคร',
#  'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร.',
#  'พิธีกรรมทางศาสนา',
#  'รอประสาน',
#  'ระบุไม่ได้',
#  'ระหว่างการสอบสวนโรค',
#  'ระหว่างสอบสวน',
#  'รับจ้างขนของที่ตลาดท่ายาง',
#  'ร้านอาหาร',
#  'ศูนย์กักกัน ผู้ต้องกัก',
#  'สถานที่ทำงาน',
#  'สถานบันเทิง',
#  'สนามมวย',
#  'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ติดเชื้อยืนยัน อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยที่ติดโควิด',
#  'สัมผัสผู้ป่วยยืนยัน',
#  'สัมผัสผู้ป่วยยืนยัน \n อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)',
#  'สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน',
#  'สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน',
#  'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน',
#  'สัมผัสผู้เดินทางจากต่างประเทศ',
#  'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)',
#  'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้',
#  'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า',
#  'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า',
#  'สัมผัสในสถานพยาบาล',
#  'อยุ่ระหว่างสอบสวน',
#  'อยู่ระหว่างการสอบสวน',
#  'อยู่ระหว่างการสอบสวน\n',
#  'อยู่ระหว่างสอบสวน',
#  'อยู่ระหว่างสอบสวนโรค',
#  'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น',
#  'อาศัย/เดินทางไปในพื้นที่ที่มีการระบาด',
#  'อื่น',
#  'อื่นๆ',
#  'เดินทางมาจากพื้นที่จังหวัดเสี่ยง',
#  'เดินทางมาจากพื้นที่มีการระบาดของโรค',
#  'เดินทางมาจากพื้นที่เสี่ยงที่มีการระบาดของโรค',
#  'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน',
#  'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานครมหานคร',
#  'ไปยังพื้นที่ที่มีการระบาด',
#  'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว',
#  'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน',
#  'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต',
#  'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar',
#  'ไปแหล่งชุมชน/สถานที่คนหนาแน่น',
#  'ไม่มีข้อมูล'}

# %% [markdown]
# ## Handling Missing Value 3 (แทนด้วย class ใหม่ (ค่าที่เหมาะสม))

# %%
set(data_cases['Unit'])
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %%
data_cases[['Unit']] = data_cases[['Unit']].fillna('ปี?')

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ## Handling Missing Value 4 (แทนด้วย ค่ากลาง)

# %% [markdown]
# ถ้าเป็น numeric ใช้ mean

# %%
data_cases[['age']].mean()
# Out:
# age    35.52947
# dtype: float64

# %%
data_cases[['age']].dropna().mean()
# Out:
# age    35.52947
# dtype: float64

# %%
# หา mean
avg_age = data_cases[['age']].mean()
# เติม mean ลงไปแทนค่า missing
data_cases[['age']] = data_cases[['age']].fillna(avg_age)

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                      False
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['age']].mean()
# Out:
# age    35.52947
# dtype: float64

# %% [markdown]
# ถ้าเป็น norminal (ตัวหนังสือ) จะใช้ mode

# %%
data_cases[['nationality']].mode()
# Out:
#   nationality
# 0    Thailand

# %%
data_cases[['nationality']].mode().iloc[0,0] #เลือกใช้ได้ตามใจเรา
# Out:
# 'Thailand'

# %%
data_cases['nationality'].mode() #เลือกใช้ได้ตามใจเรา
# Out:
# 0    Thailand
# dtype: object

# %%
# หา mode
mode_nation = data_cases[['nationality']].mode().iloc[0,0]
# เติม mean ลงไปแทนค่า missing
data_cases[['nationality']] = data_cases[['nationality']].fillna(mode_nation)

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ถ้าเป็น ordinal ใช้ medium

# %% [markdown]
# ## เติมด้วยค่าของ column ใกล้เคียง

# %%
data_cases.head(20)
# Out:
#     No. announce_date  ... province_of_onset district_of_onset
# 0     1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1     2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2     3     22/1/2020  ...            นครปฐม             เมือง
# 3     4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4     5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5     6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6     7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# 7     8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 8     9     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 9    10     28/1/2020  ...           นนทบุรี               NaN
# 10   11     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 11   12     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 12   13     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 13   14     28/1/2020  ...            ภูเก็ต             เมือง
# 14   15     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 15   16     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 16   17     31/1/2020  ...         เชียงใหม่             หางดง
# 17   18     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 18   19     31/1/2020  ...     กรุงเทพมหานคร               NaN
# 19   20      4/2/2020  ...     กรุงเทพมหานคร               NaN
#
# [20 rows x 11 columns]

# %% [markdown]
# ## Handling Missing Value 5 (แทนด้วย ค่ากลางของ samples ใน class เดียวกัน)

# %%
data_cases2 = pd.read_csv(os.path.join(path, 'confirmed-cases.csv'))
data_cases2
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# # Select data by valuse [PD]

# %% [markdown]
# การเลือก record สามารถเลือกโดยใช้ list ของ boolean ```list ของ boolean``` (ความยาวของ list เท่ากับ จำนวน record)
#
# ``` ชื่อตาราง[list ของ boolean] ```

# %% [markdown]
# #### สร้าง list ของ boolean

# %%
data_cases2['risk'] == 'ทัณฑสถาน/เรือนจำ'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 512617     True
# 512618     True
# 512619     True
# 512620     True
# 512621     True
# Name: risk, Length: 512622, dtype: bool

# %% [markdown]
# #### นำ list ของ boolean มาเลือกค่าในตาราง

# %%
data_cases2[data_cases2['risk'] == 'ทัณฑสถาน/เรือนจำ']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 100018  100019     16/5/2021  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 100019  100020     16/5/2021  ...        ฉะเชิงเทรา  เมืองฉะเชิงเทรา‎
# 101468  101469     17/5/2021  ...               NaN               NaN
# 101469  101470     17/5/2021  ...               NaN               NaN
# 101470  101471     17/5/2021  ...               NaN               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [41331 rows x 11 columns]

# %% [markdown]
# สร้าง list ของ boolean

# %%
#recode อายุที่มากกว่า 70
data_cases2['age'] > 70
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 512617    False
# 512618    False
# 512619    False
# 512620    False
# 512621    False
# Name: age, Length: 512622, dtype: bool

# %% [markdown]
# เลือก

# %%
data_cases2[data_cases2['age'] > 70]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 7            8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 82          83     15/3/2020  ...     กรุงเทพมหานคร               NaN
# 119        120     16/3/2020  ...        ฉะเชิงเทรา               NaN
# ...        ...           ...  ...               ...               ...
# 511418  511419     26/7/2021  ...     กรุงเทพมหานคร           ราชเทวี
# 511463  511464     26/7/2021  ...     กรุงเทพมหานคร            บางบอน
# 511488  511489     26/7/2021  ...     กรุงเทพมหานคร            บางบอน
# 511506  511507     26/7/2021  ...     กรุงเทพมหานคร       สัมพันธวงศ์
# 511561  511562     26/7/2021  ...     กรุงเทพมหานคร            ธนบุรี
#
# [11623 rows x 11 columns]

# %%
blist_age70up = data_cases2['age'] > 70

# %%
blist_female = data_cases2['sex'] == 'หญิง'
blist_female
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 512617    False
# 512618    False
# 512619    False
# 512620    False
# 512621    False
# Name: sex, Length: 512622, dtype: bool

# %% [markdown]
# เราใช้ & (and) และ | (or) ในการรวม list ของ boolean

# %%
blist_age70up & blist_female
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 512617    False
# 512618    False
# 512619    False
# 512620    False
# 512621    False
# Length: 512622, dtype: bool

# %%
data_cases2[blist_age70up & blist_female]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 7            8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 476        477     22/3/2020  ...     กรุงเทพมหานคร         ภาษีเจริญ
# 564        565     22/3/2020  ...           นนทบุรี               NaN
# ...        ...           ...  ...               ...               ...
# 511082  511083     26/7/2021  ...     กรุงเทพมหานคร         คลองสามวา
# 511128  511129     26/7/2021  ...     กรุงเทพมหานคร          ตลิ่งชัน
# 511196  511197     26/7/2021  ...     กรุงเทพมหานคร       สัมพันธวงศ์
# 511418  511419     26/7/2021  ...     กรุงเทพมหานคร           ราชเทวี
# 511463  511464     26/7/2021  ...     กรุงเทพมหานคร            บางบอน
#
# [6350 rows x 11 columns]

# %% [markdown]
# ## Quiz + Hw
#
# หา records ต่อไปนี้
#
# 1.   records ที่ กักตัวที่ขอนแก่น
# 2.   records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร
# 3.   records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม
# 4.   records ที่เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่
#
# 1.   หาอายุเฉลี่ยของคนที่พบเชื้อที่ ขอนแก่น

# %% [markdown]
# 1.records ที่ กักตัวที่ขอนแก่น

# %%
data_cases2['province_of_isolation'] == 'ขอนแก่น'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 512617    False
# 512618    False
# 512619    False
# 512620    False
# 512621    False
# Name: province_of_isolation, Length: 512622, dtype: bool

# %%
data_cases2[data_cases2['province_of_isolation'] == 'ขอนแก่น']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 505598  505599     26/7/2021  ...           ขอนแก่น           ภูเวียง
# 505599  505600     26/7/2021  ...           ขอนแก่น           ภูเวียง
# 511809  511810     26/7/2021  ...               NaN               NaN
# 511810  511811     26/7/2021  ...               NaN               NaN
# 511811  511812     26/7/2021  ...               NaN               NaN
#
# [3707 rows x 11 columns]

# %% [markdown]
# 2.record ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร

# %%
list_kh = data_cases2['province_of_isolation'] == 'ขอนแก่น'

# %%
list_cr = data_cases2['province_of_isolation'] == 'นครราชสีมา'

# %%
list_dt = data_cases2['province_of_isolation'] == 'อุดรราชธานี'

# %%
data_cases2[list_kh | list_cr | list_dt]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 189        190     18/3/2020  ...        นครราชสีมา             พิมาย
# 207        208     18/3/2020  ...     กรุงเทพมหานคร               NaN
# 212        213     18/3/2020  ...        นครราชสีมา       วังน้ำเขียว
# 284        285     20/3/2020  ...        นครราชสีมา   เมืองนครราชสีมา
# ...        ...           ...  ...               ...               ...
# 507218  507219     26/7/2021  ...               NaN               NaN
# 507219  507220     26/7/2021  ...               NaN               NaN
# 511809  511810     26/7/2021  ...               NaN               NaN
# 511810  511811     26/7/2021  ...               NaN               NaN
# 511811  511812     26/7/2021  ...               NaN               NaN
#
# [7749 rows x 11 columns]

# %% [markdown]
# 3.records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม

# %%
data_cases2[(data_cases2['district_of_onset']=='กรุงเทพมหานคร') & (data_cases2['sex']=='หญิง')]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 292        293     20/3/2020  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 318        319     20/3/2020  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 1928      1929      3/4/2020  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 30541    30542      9/4/2021  ...            ชลบุรี     กรุงเทพมหานคร
# 208455  208456     18/6/2021  ...       สมุทรปราการ     กรุงเทพมหานคร
# ...        ...           ...  ...               ...               ...
# 429001  429002     21/7/2021  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 461987  461988     23/7/2021  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 471588  471589     24/7/2021  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 471589  471590     24/7/2021  ...     กรุงเทพมหานคร     กรุงเทพมหานคร
# 488250  488251     25/7/2021  ...        ฉะเชิงเทรา     กรุงเทพมหานคร
#
# [77 rows x 11 columns]

# %% [markdown]
# 4.records ที่เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่

# %%
list_male = data_cases2['sex'] == 'ชาย'
list_age = data_cases2['age'] >=18
list_age2 = data_cases2['age'] <=22
list_cm = data_cases2['province_of_isolation'] == 'เชียงใหม่'

# %%
data_cases2[list_male & list_age & list_age2 & list_cm]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 1407      1408     30/3/2020  ...         เชียงใหม่             เมือง
# 30340    30341      9/4/2021  ...         เชียงใหม่    เมืองเชียงใหม่
# 31499    31500     10/4/2021  ...         เชียงใหม่               NaN
# 31500    31501     10/4/2021  ...         เชียงใหม่               NaN
# 31501    31502     10/4/2021  ...         เชียงใหม่               NaN
# ...        ...           ...  ...               ...               ...
# 481940  481941     25/7/2021  ...         เชียงใหม่             หางดง
# 481953  481954     25/7/2021  ...         เชียงใหม่             หางดง
# 481961  481962     25/7/2021  ...         เชียงใหม่          เชียงดาว
# 497281  497282     26/7/2021  ...         เชียงใหม่          เชียงดาว
# 497302  497303     26/7/2021  ...         เชียงใหม่             หางดง
#
# [411 rows x 11 columns]

# %% [markdown]
# 5.หาอายุเฉลี่ยของคนที่พบเชื้อที่ ขอนแก่น

# %%
list_KK_onset = data_cases2['province_of_onset'] == 'ขอนแก่น'
KK_onset = data_cases2[list_KK_onset]
KK_onset
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 507541  507542     26/7/2021  ...           ขอนแก่น               NaN
# 507542  507543     26/7/2021  ...           ขอนแก่น               NaN
# 507543  507544     26/7/2021  ...           ขอนแก่น               NaN
# 507544  507545     26/7/2021  ...           ขอนแก่น               NaN
# 507546  507547     26/7/2021  ...           ขอนแก่น               NaN
#
# [3149 rows x 11 columns]

# %%
KK_onset[['age']].mean()
# Out:
# age    34.095253
# dtype: float64

# %% [markdown]
# #### หาอายุเฉลี่ยของคนที่พบเชื้อที่ ขอนแก่น

# %%
KK_cases = data_cases2['province_of_onset'] == 'ขอนแก่น'
KK_mean = data_cases2[KK_cases]['age'].mean()
KK_mean
# Out:
# 34.0952533675433

# %% [markdown]
# ***พบที่ขอนแก่น***

# %%
data_cases2[KK_cases]
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 507541  507542     26/7/2021  ...           ขอนแก่น               NaN
# 507542  507543     26/7/2021  ...           ขอนแก่น               NaN
# 507543  507544     26/7/2021  ...           ขอนแก่น               NaN
# 507544  507545     26/7/2021  ...           ขอนแก่น               NaN
# 507546  507547     26/7/2021  ...           ขอนแก่น               NaN
#
# [3149 rows x 11 columns]

# %% [markdown]
# **เอาค่า mean ไปเติมตรง missing column 'age'**

# %%
data_KK = data_cases2[KK_cases]
data_KK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_KK[['age']] = data_KK[['age']].fillna(KK_mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_KK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                      False
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_KK
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 181        182     18/3/2020  ...           ขอนแก่น             เมือง
# 463        464     22/3/2020  ...           ขอนแก่น             เมือง
# 1467      1468     30/3/2020  ...           ขอนแก่น             เมือง
# 1971      1972      3/4/2020  ...           ขอนแก่น             เมือง
# 2638      2639     15/4/2020  ...           ขอนแก่น            น้ำพอง
# ...        ...           ...  ...               ...               ...
# 507541  507542     26/7/2021  ...           ขอนแก่น               NaN
# 507542  507543     26/7/2021  ...           ขอนแก่น               NaN
# 507543  507544     26/7/2021  ...           ขอนแก่น               NaN
# 507544  507545     26/7/2021  ...           ขอนแก่น               NaN
# 507546  507547     26/7/2021  ...           ขอนแก่น               NaN
#
# [3149 rows x 11 columns]

# %% [markdown]
# เติมค่า mean แทน missing ของ เชียงใหม่

# %%
# หาค่า mean ของเชียงใหม่
CM_cases = data_cases2['province_of_onset'] == 'เชียงใหม่'
CM_mean = data_cases2[CM_cases]['age'].mean()

# เลือกมาเฉพาะ data เชียงใหม่
data_CM = data_cases2[CM_cases]

# เติมค่า mean แทน missing
data_CM[['age']] = data_CM[['age']].fillna(CM_mean)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_CM
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 16          17     31/1/2020  ...         เชียงใหม่             หางดง
# 91          92     15/3/2020  ...         เชียงใหม่            แม่ริม
# 185        186     18/3/2020  ...         เชียงใหม่          นครพิงค์
# 192        193     18/3/2020  ...         เชียงใหม่               NaN
# 252        253     19/3/2020  ...         เชียงใหม่               NaN
# ...        ...           ...  ...               ...               ...
# 497341  497342     26/7/2021  ...         เชียงใหม่          สันกำแพง
# 497342  497343     26/7/2021  ...         เชียงใหม่               NaN
# 497343  497344     26/7/2021  ...         เชียงใหม่      -เลือกอำเภอ-
# 497344  497345     26/7/2021  ...         เชียงใหม่            แม่ริม
# 497345  497346     26/7/2021  ...         เชียงใหม่            แม่อาย
#
# [4074 rows x 11 columns]

# %% [markdown]
# #### ต่อตารางแนวแกน Y [PD]

# %%
data_CMKK = pd.concat([data_CM,data_KK])
data_CMKK
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 16          17     31/1/2020  ...         เชียงใหม่             หางดง
# 91          92     15/3/2020  ...         เชียงใหม่            แม่ริม
# 185        186     18/3/2020  ...         เชียงใหม่          นครพิงค์
# 192        193     18/3/2020  ...         เชียงใหม่               NaN
# 252        253     19/3/2020  ...         เชียงใหม่               NaN
# ...        ...           ...  ...               ...               ...
# 507541  507542     26/7/2021  ...           ขอนแก่น               NaN
# 507542  507543     26/7/2021  ...           ขอนแก่น               NaN
# 507543  507544     26/7/2021  ...           ขอนแก่น               NaN
# 507544  507545     26/7/2021  ...           ขอนแก่น               NaN
# 507546  507547     26/7/2021  ...           ขอนแก่น               NaN
#
# [7223 rows x 11 columns]

# %% [markdown]
# **Handling Missing Value 5 (แทนด้วย ค่ากลางของ samples ใน class เดียวกัน) (ต่อ)**

# %%
data_cases2
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# เติมค่า missing ให้จังหวัด

# %%
data_cases2[['province_of_onset']] = data_cases2[['province_of_onset']].fillna('ไม่มีข้อมูล')

# %% [markdown]
# หาจังหวัดทั้งหมด

# %%
all_cities = set(data_cases2['province_of_onset'])
all_cities
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธ์ุ',
#  'กาฬสิินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่่น',
#  'จ.ปัตตานี',
#  'จังหวัดร้อยเอ็ด',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชลบุุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชััยภูมิ',
#  'ชุมพร',
#  'ชุุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'ธารโต',
#  'นคนปฐม',
#  'นคปฐม',
#  'นครนาชสีมา',
#  'นครนายก',
#  'นครปฐม',
#  'นครประฐม',
#  'นครพนม',
#  'นครราชธสีมา',
#  'นครราชสีมา',
#  'นครศรธรรมาช',
#  'นครศรี',
#  'นครศรีธรรมราช',
#  'นครศรีธรรรมราช',
#  'นครศรีราชสีมา',
#  'นครศรีีธรรมราช',
#  'นครสวรรค์',
#  'นครสววรค์',
#  'นตรปฐม',
#  'นนทบุรี',
#  'นนทุบรี',
#  'นราธิวาส',
#  'นาราธิวาส',
#  'นาวัง',
#  'น่าน',
#  'บางกะปิ',
#  'บึงกาฬ',
#  'บึงโขงหลง',
#  'บึึงกาฬ',
#  'บุรีรัมย์',
#  'บ้านหลวง',
#  'ปทุมทานี',
#  'ปทุมธานี',
#  'ปทุมธานีี',
#  'ปทุุมธานี',
#  'ประจวบครีขันธ์',
#  'ประจวบคีรีขันธื',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปลายพระยา',
#  'ปัตตานี',
#  'ปัตตานี\u200b',
#  'ปัว',
#  'พม่า',
#  'พระนครศรียุธยา',
#  'พระนครศรีอยุทธยา',
#  'พระนครศรีอยุธนา',
#  'พระนครศรีอยุธยา',
#  'พระนครศีรอยุธยา',
#  'พระนครศีอยุธยา',
#  'พระนตรศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'ภูเพียง',
#  'มหาสารคราม',
#  'มหาสารคาม',
#  'มาเลเซีย',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยานนาวา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้องกวาง',
#  'ร้อยเอ็ด',
#  'ร้อยเอ็็ด',
#  'ร้อยเอ้ด',
#  'ร้้อยเอ็ด',
#  'ลพบรี',
#  'ลพบุรี',
#  'ลพบุุรี',
#  'ลอง',
#  'ลำปาง',
#  'ลำพูน',
#  'วังชิ้น',
#  'ศรีษะเกษ',
#  'ศรีสะเกษ',
#  'ศรีีสะเกษ',
#  'ศีรษะเกษ',
#  'ศีรสะเกษ',
#  'สกลนคร',
#  'สงขขลา',
#  'สงขลา',
#  'สงขลา\u200b',
#  'สตูล',
#  'สถานที่ทำงาน',
#  'สมทรสาคร',
#  'สมุทปราการ',
#  'สมุทรปราการ',
#  'สมุทรปาการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สมุทราปราการ',
#  'สมุทราสาคร',
#  'สมุทสงคราม',
#  'สมุทสาคร',
#  'สมุุทรปราการ',
#  'สมุุทรสงคราม',
#  'สมุุทรสาคร',
#  'สมุุทสาคร',
#  'สระบุรี',
#  'สระบุุรี',
#  'สระแก้ว',
#  'สรแก้ว',
#  'สอง',
#  'สองแคว',
#  'สิงห์บุรี',
#  'สุทรปราการ',
#  'สุพรรณบุรี',
#  'สุมทรสาคร',
#  'สุมุทรปราการ',
#  'สุมุทรสาคร',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุุราษฎร์ธานี',
#  'สุโขทัย',
#  'สูงเม่น',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'หนองบัวลำภูู',
#  'หนองบัวลำำภู',
#  'หนองบััวลำภู',
#  'หนองม่วงไข่',
#  'อยุธยา',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุดรธานีี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราขธานี',
#  'อุบลราชธานี',
#  'อุุดรธาน',
#  'อุุดรธานี',
#  'อุุตรดิตถ์',
#  'อุุทัยธานี',
#  'อ่างทอง',
#  'ูภูเก็ต',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เด่นชัย',
#  'เพชบุรี',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เพรชบุรี',
#  'เพรบุรี',
#  'เมือง',
#  'เมืองน่าน',
#  'เรือ',
#  'เลย',
#  'เวียงจันทร์',
#  'เวียงสา',
#  'แพร่',
#  'แม่ฮ่องสอน',
#  'ไม่มีข้อมูล',
#  'ไม่ระบุ'}

# %%
fixed_cities = []

for city in all_cities:
    # หาค่า mean X
    X_cases = data_cases2['province_of_onset'] == city
    X_mean = data_cases2[X_cases]['age'].mean()

    # เลือกมาเฉพาะ data X
    data_X = data_cases2[X_cases]

    # เติมค่า mean แทน missing
    data_X[['age']] = data_X[['age']].fillna(X_mean)

    fixed_cities.append(data_X)

data_cases2_nomissingage = pd.concat(fixed_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 409985  409986     19/7/2021  ...        กาฬสิินธุ์          ท่าคันโท
# 295978  295979      7/7/2021  ...        สมุทรปาการ   เมืองสมุทรปาการ
# 295869  295870      7/7/2021  ...       นครศรธรรมาช           หลักชัย
# 330043  330044     11/7/2021  ...             นคปฐม               NaN
# 330044  330045     11/7/2021  ...             นคปฐม             นคปฐม
# ...        ...           ...  ...               ...               ...
# 392000  392001     18/7/2021  ...         เมืองน่าน           สะเนียน
# 392002  392003     18/7/2021  ...         เมืองน่าน            บ่อสวก
# 392007  392008     18/7/2021  ...         เมืองน่าน           สะเนียน
# 448343  448344     22/7/2021  ...            สงขขลา               NaN
# 5838      5839    25/12/2020  ...              พม่า       ท่าขี้เหล็ก
#
# [512622 rows x 11 columns]

# %%
data_cases2_nomissingage.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %% [markdown]
# เติม mean ของทั้งตาราง ให้กับ missing ที่ยังเหลืออยู่

# %%
data_cases2_nomissingage[['age']] = data_cases2_nomissingage[['age']].fillna(data_cases2_nomissingage['age'].mean())

# %%
data_cases2_nomissingage.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                      False
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 409985  409986     19/7/2021  ...        กาฬสิินธุ์          ท่าคันโท
# 295978  295979      7/7/2021  ...        สมุทรปาการ   เมืองสมุทรปาการ
# 295869  295870      7/7/2021  ...       นครศรธรรมาช           หลักชัย
# 330043  330044     11/7/2021  ...             นคปฐม               NaN
# 330044  330045     11/7/2021  ...             นคปฐม             นคปฐม
# ...        ...           ...  ...               ...               ...
# 392000  392001     18/7/2021  ...         เมืองน่าน           สะเนียน
# 392002  392003     18/7/2021  ...         เมืองน่าน            บ่อสวก
# 392007  392008     18/7/2021  ...         เมืองน่าน           สะเนียน
# 448343  448344     22/7/2021  ...            สงขขลา               NaN
# 5838      5839    25/12/2020  ...              พม่า       ท่าขี้เหล็ก
#
# [512622 rows x 11 columns]

# %% [markdown]
# ## การเรียงข้อมูล [PD]

# %%
data_cases2_nomissingage = data_cases2_nomissingage.sort_values(by=['No.'])

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512618  512619     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512619  512620     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512620  512621     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512621  512622     26/7/2021  ...       ไม่มีข้อมูล               NaN
#
# [512622 rows x 11 columns]

# %% [markdown]
# ### Outlier

# %%
from matplotlib import pyplot as plt

# %%
data_dict = plt.boxplot(data_cases2_nomissingage['age'])

# %%
data_dict #curly brackets
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fce14e656d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fce14e6d790>,
#   <matplotlib.lines.Line2D at 0x7fce14e6dcd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fce14e75550>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fce14e75a10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fce14e65cd0>,
#   <matplotlib.lines.Line2D at 0x7fce14e6d250>]}

# %%
data_dict['boxes']

# %%
data_dict['boxes'][0]

# %%
data_dict['boxes'][0].get_ydata()
# Out:
# array([26., 26., 44., 44., 26.])

# %%
Q1 = data_dict['boxes'][0].get_ydata()[0]

# %%
Q1
# Out:
# 26.0

# %%
data_dict['fliers'][0].get_ydata()
# Out:
# array([74., 73., 73., ..., 83., 80., 75.])

# %%
data_dict['caps'][0].get_ydata()
# Out:
# array([1., 1.])

# %%
data_dict['caps'][1].get_ydata()
# Out:
# array([71., 71.])

# %%
cap1 = data_cases2_nomissingage['age'] >= data_dict['caps'][0].get_ydata()[0]
cap2 = data_cases2_nomissingage['age'] <= data_dict['caps'][1].get_ydata()[0]

data_cases2_nomissingage_nooutlier = data_cases2_nomissingage[cap1 & cap2]
data_cases2_nomissingage_nooutlier
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5            6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6            7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512618  512619     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512619  512620     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512620  512621     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512621  512622     26/7/2021  ...       ไม่มีข้อมูล               NaN
#
# [502350 rows x 11 columns]

# %%
data_dict = plt.boxplot(data_cases2_nomissingage_nooutlier['age'])

# %% [markdown]
# ตัด outlier แบบ manual

# %%
data_cases2_nomissingage[data_cases2_nomissingage['province_of_onset'] != 'ลอง']
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512618  512619     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512619  512620     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512620  512621     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512621  512622     26/7/2021  ...       ไม่มีข้อมูล               NaN
#
# [512616 rows x 11 columns]

# %% [markdown]
# ####Quiz 5
# เขียนฟังก์ชั่น คำนวณ หา Q1,Q2,Q3,IQR,min,max โดยรับ input เป็น output ของ boxplot
#
# ```python
# def box_vals(box_out_dict):
#     #your code1
#     .
#     .
#     .
#     #your codex
#     return q1,q2,q3,iqr,vmin,vmix
# ```

# %%
def box_vals(box_out_dict):
    #ส่วนโค้ด
    q1 = data_dict['boxes'][0].get_ydata()[0]
    q2 = data_dict['boxes'][0].get_ydata()[1]
    q3 = data_dict['boxes'][0].get_ydata()[2]
    iqr = q3 - q1
    vmin = min(data_dict['boxes'][0].get_ydata())
    vmax = max(data_dict['boxes'][0].get_ydata())
    #ส่วนแสดงผล
    print(f'Q1 = {q1}')
    print(f'Q2 = {q2}')
    print(f'Q3 = {q3}')
    print(f'IQR = {iqr}')
    print(f'min = {vmin}')
    print(f'max = {vmax}')
    #ส่วน return
    #print('ค่าของ Q1,Q2,Q3,IQR,vmin,vmax ตามลำดับ ดังนี้')
    return ##q1,q2,q3,iqr,vmin,vmax

# %%
box_vals(data_dict)
# Out:
# Q1 = 25.0
# Q2 = 25.0
# Q3 = 43.0
# IQR = 18.0
# min = 25.0
# max = 43.0

# %%
#เฉลย
def box_vals(box_out_dict) :
        Q1 = box_out_dict['boxes'][0].get_ydata()[0] 
        Q2 = box_out_dict['medians'][0].get_ydata()[0]
        Q3 = box_out_dict['boxes'][0].get_ydata()[2]
        IQR =  Q3 - Q1
        vmin =  box_out_dict['caps'][0].get_ydata()[0]
        vmax =  box_out_dict['caps'][1].get_ydata()[0] 
        return Q1,Q2,Q3,IQR,vmin,vmax

# %%
box_vals(data_dict)
# Out:
# (25.0, 35.0, 43.0, 18.0, 1.0, 70.0)

# %%
data_dict = plt.boxplot(data_cases2_nomissingage_nooutlier['age'],vert=False) #plotกราฟเป็นแนวนอน

# %%
data_dict['boxes'][0].get_xdata()
# Out:
# array([25., 25., 43., 43., 25.])

# %% [markdown]
# ##HW หรือ Quiz (III) แก้ให้ function box_vals สามารถรับ input ที่ box plot วาดแบบแนวนอนได้ (vert = False)

# %%
#เฉลย
def box_vals(box_out_dict, vert = True):
    if vert == True:
        Q1 = box_out_dict['boxes'][0].get_ydata()[0]
        Q2 = box_out_dict['medians'][0].get_ydata()[0]
        Q3 = box_out_dict['boxes'][0].get_ydata()[2]
        IQR = Q3 - Q1 
        vmin = box_out_dict['caps'][0].get_ydata()[0]
        vmax = box_out_dict['caps'][1].get_ydata()[0]
    else:
        Q1 = box_out_dict['boxes'][0].get_xdata()[0]
        Q2 = box_out_dict['medians'][0].get_xdata()[0]
        Q3 = box_out_dict['boxes'][0].get_xdata()[2]
        IQR = Q3 - Q1 
        vmin = box_out_dict['caps'][0].get_xdata()[0]
        vmax = box_out_dict['caps'][1].get_xdata()[0]

    return Q1,Q2,Q3,IQR,vmin,vmax

# %%
data_dict_x = plt.boxplot(data_cases2_nomissingage_nooutlier['age'],vert=False)

# %%
data_dict_y = plt.boxplot(data_cases2_nomissingage_nooutlier['age'])

# %%
box_vals(data_dict_y)
# Out:
# (25.0, 35.0, 43.0, 18.0, 1.0, 70.0)

# %%
box_vals(data_dict_x)
# Out:
# (0.925, 0.925, 1.075, 0.1499999999999999, 0.9625, 0.9625)

# %% [markdown]
# ##Pandas'looping.(ilerroe)

# %%
data_cut =data_cases2_nomissingage.iloc[:10,:] #ใส่ชื่อ    คอลัมน์ที่เราต้องการ
data_cut
# Out:
#    No. announce_date  ... province_of_onset district_of_onset
# 0    1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1    2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2    3     22/1/2020  ...            นครปฐม             เมือง
# 3    4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4    5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# 5    6     25/1/2020  ...     กรุงเทพมหานคร               NaN
# 6    7     26/1/2020  ...     กรุงเทพมหานคร               NaN
# 7    8     26/1/2020  ...   ประจวบคีรีขันธ์            หัวหิน
# 8    9     28/1/2020  ...     กรุงเทพมหานคร               NaN
# 9   10     28/1/2020  ...           นนทบุรี               NaN
#
# [10 rows x 11 columns]

# %%
for record in data_cut.iterrows():
    print(record[1]['province_of_isolation'])
    print('new row')
# Out:
# กรุงเทพมหานคร
# new row
# กรุงเทพมหานคร
# new row
# นครปฐม
# new row
# กรุงเทพมหานคร
# new row
# นนทบุรี
# new row
# กรุงเทพมหานคร
# new row
# กรุงเทพมหานคร
# new row
# ประจวบคีรีขันธ์
# new row
# กรุงเทพมหานคร
# new row
# นนทบุรี
# new row

# %%
for index in range(data_cut.shape[0]):
    print(data_cut.iloc[index,7])
    print('new row')
# Out:
# กรุงเทพมหานคร
# new row
# กรุงเทพมหานคร
# new row
# นครปฐม
# new row
# กรุงเทพมหานคร
# new row
# นนทบุรี
# new row
# กรุงเทพมหานคร
# new row
# กรุงเทพมหานคร
# new row
# ประจวบคีรีขันธ์
# new row
# กรุงเทพมหานคร
# new row
# นนทบุรี
# new row

# %% [markdown]
# #การรวมตาราง Data integration (ต่อตารางในแนวแกน x)

# %%
os.path.join(path,'search_click.csv')
# Out:
# '/content/drive/My Drive/DWDM2021_DATA/search_click.csv'

# %%
search_click = pd.read_csv(os.path.join(path,'search_click.csv'))
w_restaurant = pd.read_csv(os.path.join(path,'w_restaurant.csv'))

# %%
search_click.head()
# Out:
#   click_timestamp                             search_id  ...  time_diff_nanos   ads
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1  ...     2.222400e+15  True
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e  ...     4.608380e+14  True
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224  ...     2.581490e+15  True
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b  ...     1.404580e+15  True
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639  ...     9.333590e+14  True
#
# [5 rows x 6 columns]

# %%
search_click.shape
# Out:
# (1048575, 6)

# %%
print(w_restaurant.shape)
w_restaurant.head()
# Out:
# (246847, 32)
#    id              name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 0   2  นครินทร์ทันตกรรม          2  ...               NaN          NaN      NaN
# 1   4      Corner House          1  ...               NaN          NaN      NaN
# 2   5    วัดโลกยสุธาราม          4  ...               NaN          NaN      NaN
# 3   6    นันท์คาราโอเกะ          1  ...               NaN          NaN      NaN
# 4   7       Buono Caffe          1  ...               NaN          NaN      NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# อยากได้ข้อมูลร้านค้าที่คนค้นหาล่าสุด 100 ร้าน

# %%
search100 = search_click.iloc[-100:,:]
search100
# Out:
#         click_timestamp  ...    ads
# 1048475         19:00.5  ...  False
# 1048476         18:50.9  ...  False
# 1048477         45:58.0  ...  False
# 1048478         49:08.8  ...  False
# 1048479         19:25.9  ...  False
# ...                 ...  ...    ...
# 1048570         05:28.8  ...  False
# 1048571         15:28.8  ...  False
# 1048572         11:49.4  ...  False
# 1048573         10:33.7  ...  False
# 1048574         13:51.4  ...  False
#
# [100 rows x 6 columns]

# %% [markdown]
# 1.   รวม 2 ตารางเข้าด้วยกัน
# 2.   เลือกมาเฉพาะบาง column จากอีกตารางหนึ่งมาแปะไว้

# %% [markdown]
# ###รวม 2 ตาราง (.merge())

# %%
merged_table = search100.merge(w_restaurant,how='left',left_on='business_id',right_on='id')
merged_table
# Out:
#    click_timestamp  ... delivery
# 0          19:00.5  ...      NaN
# 1          18:50.9  ...      NaN
# 2          45:58.0  ...      NaN
# 3          49:08.8  ...      NaN
# 4          19:25.9  ...      NaN
# ..             ...  ...      ...
# 95         05:28.8  ...      NaN
# 96         15:28.8  ...      NaN
# 97         11:49.4  ...      1.0
# 98         10:33.7  ...      1.0
# 99         13:51.4  ...      NaN
#
# [100 rows x 38 columns]

# %% [markdown]
# ###เลือกมาเฉพาะ column ที่ต้องการมาแปะ (.map())

# %%
search100['business_name'] = search100['business_id'].map(w_restaurant.set_index('id')['name'])
search100 #ดูว่า business_id มีชื่อร้านว่าอะไร
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         click_timestamp  ...              business_name
# 1048475         19:00.5  ...  บ้านหญิง อีสาน แอนด์ กริล
# 1048476         18:50.9  ...                   ไก่อากง
# 1048477         45:58.0  ...               อร่อย@หัวหิน
# 1048478         49:08.8  ...               อร่อย@หัวหิน
# 1048479         19:25.9  ...                ชาไทยข่อลดา
# ...                 ...  ...                        ...
# 1048570         05:28.8  ...                เสกแจ่วฮ้อน
# 1048571         15:28.8  ...      ก๋วยเตี๋ยวหมูหน่อกะลา
# 1048572         11:49.4  ...        Laemcharoen Seafood
# 1048573         10:33.7  ...       เอี่ยวไถ่ สุกี้โบราณ
# 1048574         13:51.4  ...                    Icy-me
#
# [100 rows x 7 columns]

# %% [markdown]
# ## \* **bold textตารางรอง (ตารางข้างขวา) ต้องไม่มี index ซ้ำ**\*

# %% [markdown]
# #### **Projectกลุ่ม** ####
# *   Present 31 ส.ค. 64
# *   ข้อมูลที่ไปดึงมาจาก 3 แหล่ง
# *   แสดงวิธีการโหลด
# *   ความเชื่อมโยงของ 3 ตาราง (index)

# %% [markdown]
# ##Group by (pandas)

# %%
search100.groupby('business_id').count()
# Out:
#              click_timestamp  search_id  ...  ads  business_name
# business_id                              ...
# 9640.0                     1          1  ...    1              1
# 11387.0                    1          1  ...    1              1
# 12133.0                    1          1  ...    1              1
# 44441.0                    3          3  ...    3              3
# 61441.0                    4          4  ...    4              4
# ...                      ...        ...  ...  ...            ...
# 321885.0                   1          1  ...    1              1
# 323374.0                   1          1  ...    1              1
# 331866.0                   1          1  ...    1              1
# 333433.0                   1          1  ...    1              1
# 338544.0                   1          1  ...    1              1
#
# [70 rows x 6 columns]

# %% [markdown]
# ####ร้านไหนมีคน click เข้าไปดูมากที่สุด โดยพิจารณาจากการ search 100 ครั้งล่าสุด

# %%
search100.groupby('business_id').count().sort_values(by=['search_id'],ascending=False)
# Out:
#              click_timestamp  search_id  ...  ads  business_name
# business_id                              ...
# 130270.0                   5          5  ...    5              5
# 61441.0                    4          4  ...    4              4
# 98956.0                    4          4  ...    4              4
# 109141.0                   3          3  ...    3              3
# 207208.0                   3          3  ...    3              3
# ...                      ...        ...  ...  ...            ...
# 196321.0                   1          1  ...    1              1
# 11387.0                    1          1  ...    1              1
# 204481.0                   1          1  ...    1              1
# 206253.0                   1          1  ...    1              1
# 338544.0                   1          1  ...    1              1
#
# [70 rows x 6 columns]

# %%
w_restaurant[w_restaurant['id']==130270]
# Out:
#            id         name  domain_id  ...  hotel_restaurant pet_friendly delivery
# 83878  130270  Audrey Café          1  ...               NaN          NaN      NaN
#
# [1 rows x 32 columns]

# %% [markdown]
# ####แต่ละจังหวัดมีอายุของคนที่ตรวจพบโรคเป็นกี่ปี

# %%
data_cases2
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512618  512619     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512619  512620     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512620  512621     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512621  512622     26/7/2021  ...       ไม่มีข้อมูล               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases2.dropna(subset=['age']).groupby('province_of_onset').mean().sort_values(by=['age'])
# Out:
#                          No.   age
# province_of_onset
# นครศรีีธรรมราช     378103.00   2.0
# ปลายพระยา          378139.00  15.0
# จ.ปัตตานี          342312.00  16.0
# สมทรสาคร           507280.00  19.0
# นาวัง              312748.00  19.0
# ...                      ...   ...
# พระนครศีอยุธยา     367889.00  54.5
# ยานนาวา            384424.00  57.0
# สมุุทรสงคราม       417892.75  58.0
# ศีรษะเกษ           129937.00  66.0
# นคนปฐม             384846.00  67.0
#
# [171 rows x 2 columns]

# %% [markdown]
# #HW + Quiz
#
# 1.   (จากตาราง w_restaurant กับ search_click) หาจังหวัดที่มีคนกดเข้าไปดูผลการ search 3 อันดับแรก
# 2.   (จากตาราง w_restaurant กับ search_click) เมืองไหนที่มีค่าเฉลี่ยของ 'weighted_average_rating' สูงที่สุด
# 3.   (จากตาราง confirmed-cases) เรียงลำดับ risk ที่มีคนติดโรค 5 อันดับแรก
# 4.   (จากตาราง confirmed-cases) หาจังหวัดที่มีคนกักตัวมากที่สุด 10 อันดับแรก

# %% [markdown]
# **1. (จากตาราง w_restaurant กับ search_click) หา จังหวัดที่มีคนกดเข้าไปดูผลการ search 3 อันดับแรก**

# %%
merged_table.groupby('city_name').count()
# Out:
#                              click_timestamp  search_id  ...  pet_friendly  delivery
# city_name                                                ...
# Bangkok Metropolitan Region               83         83  ...             4        13
# Chaiyaphum                                 1          1  ...             0         0
# Chiang Mai                                 1          1  ...             0         0
# Chon Buri                                  5          5  ...             2         0
# Hua Hin                                    2          2  ...             0         0
# Nakhon Si Thammarat                        1          1  ...             0         0
# Nan                                        1          1  ...             0         0
# Phetchaburi                                1          1  ...             0         0
# Prachin Buri                               1          1  ...             0         0
# Samut Songkhram                            1          1  ...             0         0
# Suphan Buri                                1          1  ...             0         0
# สงขลา                                      1          1  ...             0         0
# เขาใหญ่                                    1          1  ...             0         0
#
# [13 rows x 37 columns]

# %%
search3 = merged_table.groupby('city_name').count().sort_values(by=['search_id'],ascending=False)
search3
# Out:
#                              click_timestamp  search_id  ...  pet_friendly  delivery
# city_name                                                ...
# Bangkok Metropolitan Region               83         83  ...             4        13
# Chon Buri                                  5          5  ...             2         0
# Hua Hin                                    2          2  ...             0         0
# Chaiyaphum                                 1          1  ...             0         0
# Chiang Mai                                 1          1  ...             0         0
# Nakhon Si Thammarat                        1          1  ...             0         0
# Nan                                        1          1  ...             0         0
# Phetchaburi                                1          1  ...             0         0
# Prachin Buri                               1          1  ...             0         0
# Samut Songkhram                            1          1  ...             0         0
# Suphan Buri                                1          1  ...             0         0
# สงขลา                                      1          1  ...             0         0
# เขาใหญ่                                    1          1  ...             0         0
#
# [13 rows x 37 columns]

# %%
search3_cut = search3.iloc[:3,1:2]  
search3_cut #จังหวัดที่มีคนกดเข้าไปดูผลการ search 3 อันดับแรก
# Out:
#                              search_id
# city_name
# Bangkok Metropolitan Region         83
# Chon Buri                            5
# Hua Hin                              2

# %% [markdown]
# **2.(จากตาราง w_restaurant กับ search_click) เมืองไหนที่มีค่าเฉลี่ยของ 'weighted_average_rating' สูงที่สุด**

# %%
merged_table.groupby('city_name').count()
# Out:
#                              click_timestamp  search_id  ...  pet_friendly  delivery
# city_name                                                ...
# Bangkok Metropolitan Region               83         83  ...             4        13
# Chaiyaphum                                 1          1  ...             0         0
# Chiang Mai                                 1          1  ...             0         0
# Chon Buri                                  5          5  ...             2         0
# Hua Hin                                    2          2  ...             0         0
# Nakhon Si Thammarat                        1          1  ...             0         0
# Nan                                        1          1  ...             0         0
# Phetchaburi                                1          1  ...             0         0
# Prachin Buri                               1          1  ...             0         0
# Samut Songkhram                            1          1  ...             0         0
# Suphan Buri                                1          1  ...             0         0
# สงขลา                                      1          1  ...             0         0
# เขาใหญ่                                    1          1  ...             0         0
#
# [13 rows x 37 columns]

# %%
searchrating = merged_table.groupby('city_name').count().sort_values(by=['weighted_average_rating'],ascending=False)
searchrating
# Out:
#                              click_timestamp  search_id  ...  pet_friendly  delivery
# city_name                                                ...
# Bangkok Metropolitan Region               83         83  ...             4        13
# Chon Buri                                  5          5  ...             2         0
# Hua Hin                                    2          2  ...             0         0
# Chaiyaphum                                 1          1  ...             0         0
# Chiang Mai                                 1          1  ...             0         0
# Nakhon Si Thammarat                        1          1  ...             0         0
# Nan                                        1          1  ...             0         0
# Phetchaburi                                1          1  ...             0         0
# Prachin Buri                               1          1  ...             0         0
# Samut Songkhram                            1          1  ...             0         0
# Suphan Buri                                1          1  ...             0         0
# สงขลา                                      1          1  ...             0         0
# เขาใหญ่                                    1          1  ...             0         0
#
# [13 rows x 37 columns]

# %%
searchrating_cut = searchrating.iloc[:1,13:14] 
searchrating_cut #เมืองที่มีค่าเฉลี่ยสูงสุด
# Out:
#                              weighted_average_rating
# city_name
# Bangkok Metropolitan Region                       83

# %% [markdown]
# **3.(จากตาราง confirmed-cases) เรียงลำดับ risk ที่ทำให้คนติดโรค 5 อันดับแรก**

# %%
data_cases
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...               NaN               NaN
# 512618  512619     26/7/2021  ...               NaN               NaN
# 512619  512620     26/7/2021  ...               NaN               NaN
# 512620  512621     26/7/2021  ...               NaN               NaN
# 512621  512622     26/7/2021  ...               NaN               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases2_nomissingage
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 512617  512618     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512618  512619     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512619  512620     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512620  512621     26/7/2021  ...       ไม่มีข้อมูล               NaN
# 512621  512622     26/7/2021  ...       ไม่มีข้อมูล               NaN
#
# [512622 rows x 11 columns]

# %%
data_cases2_nomissingage_nooutlier.groupby('risk').count()
# Out:
#                                                      No.  ...  district_of_onset
# risk                                                      ...
# 2.สัมผัสผู้ติดเชื้อ                                   10  ...                  2
# ACF รองเมือง                                          23  ...                  0
# ACF สนามกีฬาธูปะเตมีย์                                23  ...                  0
# ACF สนามกีฬาไทย-ญี่ปุ่น                              135  ...                  0
# ACF สีลม                                             108  ...                  0
# ...                                                  ...  ...                ...
# ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว      15412  ...              13373
# ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน                 1  ...                  1
# ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต                850  ...                802
# ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar      1  ...                  1
# ไปแหล่งชุมชน/สถานที่คนหนาแน่น                         17  ...                  0
#
# [130 rows x 10 columns]

# %%
risk = data_cases2_nomissingage_nooutlier.groupby('risk').count().sort_values(by=['province_of_onset'],ascending=False)
risk
# Out:
#                                                      No.  ...  district_of_onset
# risk                                                      ...
# สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้       178308  ...             164575
# การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน   80147  ...              71911
# อยู่ระหว่างการสอบสวน                               59927  ...              38560
# อื่นๆ                                              52118  ...              41112
# ทัณฑสถาน/เรือนจำ                                   41221  ...               7822
# ...                                                  ...  ...                ...
# สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน         1  ...                  0
# สัมผัสผู้ป่วยยืนยัน อยุ๋ระหว่างสอบสวน                  1  ...                  1
# ตลาด                                                   1  ...                  1
# ตรวจสุขภาพแรงงานต่างด้าว                               1  ...                  1
# SHUI                                                   1  ...                  1
#
# [130 rows x 10 columns]

# %%
risk_cut = risk.iloc[:5,8:9] 
risk_cut #เรียงลำดับ risk ที่ทีให้คนติดโรค 5 อันดับแรก
# Out:
#                                                   province_of_onset
# risk
# สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                  178308
# การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน              80147
# อยู่ระหว่างการสอบสวน                                          59927
# อื่นๆ                                                         52118
# ทัณฑสถาน/เรือนจำ                                              41221

# %% [markdown]
# **4.(จากตาราง confirmed-cases) หาจังหวัดที่มีคนกักตัวมากที่สุด 10 อันดับแรก**

# %%
data_cases2_nomissingage_nooutlier.groupby('province_of_onset').count()
# Out:
#                       No.  announce_date  ...    risk  district_of_onset
# province_of_onset                         ...
# กระบี่                763            763  ...     761                644
# กรุงเทพมหานคร      129503         129503  ...  129461             108913
# กัมพูชา                 6              6  ...       6                  2
# กาญจนบุรี            2018           2018  ...    2014               1956
# กาฬสินธิ์               3              3  ...       3                  3
# ...                   ...            ...  ...     ...                ...
# เวียงสา                 5              5  ...       5                  5
# แพร่                  436            436  ...     436                426
# แม่ฮ่องสอน             89             89  ...      89                 80
# ไม่มีข้อมูล         64345          64345  ...   63957               2096
# ไม่ระบุ                 8              8  ...       8                  7
#
# [185 rows x 10 columns]

# %%
isolation = data_cases2_nomissingage_nooutlier.groupby('province_of_onset').count().sort_values(by=['province_of_isolation'],ascending=False)
isolation
# Out:
#                       No.  announce_date  ...    risk  district_of_onset
# province_of_onset                         ...
# กรุงเทพมหานคร      129503         129503  ...  129461             108913
# ไม่มีข้อมูล         64345          64345  ...   63957               2096
# สมุทรสาคร           36572          36572  ...   36560              35323
# สมุทรปราการ         34263          34263  ...   34230              33109
# นนทบุรี             26289          26289  ...   26276              20984
# ...                   ...            ...  ...     ...                ...
# นครศรีีธรรมราช          1              1  ...       1                  1
# นครสววรค์               1              1  ...       1                  1
# หนองบัวลำภูู            1              1  ...       1                  1
# นตรปฐม                  1              1  ...       1                  1
# ยานนาวา                 1              1  ...       1                  1
#
# [185 rows x 10 columns]

# %%
isolation_cut = isolation.iloc[:10,7:8]
isolation_cut #จังหวัดที่มีคนกักตัวมากที่สุด 10 อันดับแรก
# Out:
#                    province_of_isolation
# province_of_onset
# กรุงเทพมหานคร                     129498
# ไม่มีข้อมูล                        63968
# สมุทรสาคร                          36466
# สมุทรปราการ                        34260
# นนทบุรี                            26288
# ชลบุรี                             21996
# ปทุมธานี                           21878
# นครปฐม                             13172
# เพชรบุรี                           11112
# สงขลา                              10219
